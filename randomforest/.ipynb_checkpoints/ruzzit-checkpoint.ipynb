# %%
import requests
import pandas as pd
import numpy as np
import json
import time
from selenium import webdriver

import codecs

pd.set_option('display.max_colwidth', 200)

#browser = webdriver.PhantomJS()
#browser.set_window_size(1080, 800)
#browser.get("http://www.ruzzit.com/")
#time.sleep(3)
#pg_scroll_count = 50
#while pg_scroll_count:
 #   browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
  #  time.sleep(15)
   # pg_scroll_count -= 1

#titles = browser.find_elements_by_class_name("article_title")
#link_class = browser.find_elements_by_class_name("link_read_more_article")
#stats = browser.find_elements_by_class_name("ruzzit_statistics_area")

#all_data = []
#for title, link, stat in zip(titles, link_class, stats):
 #   all_data.append((title.text,\
  #                   link.get_attribute("href"),\
   #                  stat.find_element_by_class_name("col-md-12").text.split(' shares')[0],
    #                 stat.find_element_by_class_name("col-md-12").text.split('tweets\n')[1].split('likes\n0')[0],
     #                stat.find_element_by_class_name("col-md-12").text.split('1\'s\n')[1].split(' pins')[0],
      #               stat.find_element_by_class_name("col-md-12").text.split('pins\n')[1]
       #             ))
    
#df = pd.DataFrame(all_data, columns = ['title', 'link', 'fb', 'lnkdn', 'pins', 'date'])

all_data = list(codecs.open('d:/python_work/machine-learning/randomforest/ruzzit-utf8.txt', 'r', 'utf-8'))

group_data = ['']*(len(all_data)// 6)

for line in all_data:
    group_data[(all_data.index(line) // 6)] += line
    #print(group_data[(all_data.index(line) // 6)])
group_data

def parse_line(row):
    row = row.split(',')[0]
    return row

#df.applymap(parse_line)

List = [(['']* 6) for i in range((len(all_data)// 6))]

df = pd.DataFrame(columns = ['title', 'link', 'fb', 'lnkdn', 'pins', 'date'])

for line in all_data:
    List[int(all_data.index(line)/ 6)][int(all_data.index(line)% 6)] = line
    
df = pd.DataFrame(List, columns = ['title', 'link', 'fb', 'lnkdn', 'pins', 'date'])
df = df.applymap(lambda x: x.strip())    
#df = df.applymap(lambda x: x.split("'")[1] if "'" in str(x) else x)

def check_home(x):
    if '.com' in x:
        if len(x.split('.com')[1]) < 2:
            return 1
        else:
            return 0
    else:
        return 0
    
def check_img(x):
    if '.gif' in x or '.jpg' in x :
        return 1
    else:
        return 0

from bs4 import BeautifulSoup
def text_from_html(x):
    try:
        soup = BeautifulSoup(x, 'lxml')
        return soup.get_text()
    except:
        return None

df
# Out:
#                                                                                title  \
# 0                   ﻿ ("Walker flap exposes GOP rift on Iowa's sacred status - CNN",
# 1                               ('What Career Should You Actually Have? - BuzzFeed',
# 2                               ('What State Do You Actually Belong In? - BuzzFeed',
# 3                                   ('Which "Grease" Pink Lady Are You? - BuzzFeed',
# 4                     ('https://media.giphy.com/media/xTcnT6Kc5pbyZl8VzO/giphy.gif',
# 5    ("Optimistic People All Have One Thing In Common: They're Always Late - Elite",
# 6    ("Fast Food Workers: You Don't Deserve $15 an Hour to Flip Burgers, and That'",
# 7         ("Zombie-themed 'Walking Dead' cruise setting sail in January - Fox News",
# 8                          ('https://media.giphy.com/media/9NAXpI52kjBjG/giphy.gif',
# 9     ("Man Builds 'Dog Train' To Take Rescued Pups Out On Little Adventures - The",
# 10                    ('https://media.giphy.com/media/3o8doO4sqbyDf1LjlC/giphy.gif',
# 11   ('https://49.media.tumblr.com/724a51968d0332bcaac2cc53b1a11516/tumblr_o0t70sd',
# 12   ('https://s-media-cache-ak0.pinimg.com/originals/ca/eb/17/caeb17ce45dd6b29634',
# 13                       ('15 hilarious parenting comics that are almost too real.',
# 14               ('33 Insanely Clever Things Your Small Apartment Needs - BuzzFeed',
# 15   ('Donald Trump has flip-flopped so much that Stephen Colbert hosted a Trump v',
# 16   ('That time 16-year-old Malala Yousafzai left Jon Stewart speechless with com',
# 17   ("21 Things You Only Know If You've Been Best Friends For 10 Years - BuzzFeed",
# 18   ("Husband Says He Can't Afford His Wife As A Stay-At-Home Mom And His ... - I",
# 19             ("18 Photos That Won't Make Sense To Sisterless Families - BuzzFeed",
# 20    ('Dad Picks Her Up From School And Finds Out She’s Been Bullied – Watch What',
# 21    ('Every September 11, I Remember This Surprising Story About Steve Buscemi -',
# 22                  ("No, It's Not Your Opinion. You're Just Wrong - Houston Press",
# 23   ("A Mom's Social Media Post Shatters Lives in AT&T's Gut-Wrenching Ad - Creat",
# 24      ('19 Vintage Easter Bunny Photos That Will Make Your Skin Crawl - BuzzFeed',
# 25                 ("CLICK HERE to support COMET: World's First Buoyant Smartphone",
# 26            ('London Fashion Week: Sibling Fall/Winter 2015 - The New York Times',
# 27   ('Dear white Facebook friends: I need you to respect what Black America is fe',
# 28    ("This Might Look Like A Nursing Home Or A Preschool, But It's Much Better -",
# 29     ('29 Dollar Store Finds That Will Keep Your Kids Busy All Summer - BuzzFeed',
# ..                                                                               ...
# 480  ('A Harry Potter-Themed Bar Just Opened And You Have To Pay Your Respects - B',
# 481   ('Final Draft of Climate Change Accord to Be Released on Saturday - New York',
# 482    ('Tesla’s $3,000 Powerwall Will Let Households Run Entirely On Solar Energy',
# 483   ('I was held hostage by Isis. They fear our unity more than our airstrikes -',
# 484            ("Cold And Snow Predicted By Farmers' Almanac - The Huffington Post",
# 485               ('25 Pictures That Perfectly Sum Up Working In Retail - BuzzFeed',
# 486  ('A Former Planned Parenthood Employee Just Tweeted All the Horrifying Acts o',
# 487     ('The Families Funding the 2016 Presidential Election - The New York Times',
# 488           ('19 Small Awards Anyone With Anxiety Deserves To Receive - BuzzFeed',
# 489   ('There Will Be A Full Moon On Christmas For The First Time In Decades - The',
# 490  ("If You're Liberal and You Think Hillary Clinton Is Corrupt and Untrustworth",
# 491                 ("13 things mentally strong people don't do - Business Insider",
# 492  ('22 Things People Who Are Chronically Early Will Totally Understand - BuzzFe',
# 493           ('If Motivational Posters Were For People Who Hate People - BuzzFeed',
# 494   ('Mariah Carey Casually Sings Along To Her Greatest Hits With James Corden -',
# 495                     ('Angelina Jolie Pitt: Diary of a Surgery - New York Times',
# 496         ('Why My Husband Will Always Come Before My Kids - The Huffington Post',
# 497                 ('Supreme Court Ruling and Christian Outrage - Huffington Post',
# 498  ('California Set To Give Solar Panels To Low-Income Families For Free - IFLSc',
# 499        ('14 Reasons Why The Irish Goodbye Is The Best Exit Strategy - BuzzFeed',
# 500                                          ('A Toxic Work World - New York Times',
# 501  ("Reporter instantly regrets asking man what he'd do with Powerball money - M",
# 502  ('Groom Makes Wedding Vows To 3-Year-Old Stepdaughter In Emotional Video - Th',
# 503  ('Archaeologists To Ben Carson: Ancient Egyptians Wrote Down Why The Pyramids',
# 504               ('10 Things to keep in Mind When Loving a Highly Creative Person',
# 505  ('Yogi Berra, Master Catcher With a Goofy Wit, Dies at 90 - The New York Time',
# 506  ("Do You Bite Your Nails? It Might Mean You're A Perfectionist - The Huffingt",
# 507   ("Why Our Children Don't Think There Are Moral Facts - New York Times (blog)",
# 508                        ('The Most Mysterious Star in Our Galaxy - The Atlantic',
# 509                       ("'Stay-at-Home Mom' Is Not a Real Job - Huffington Post",
#
#                                                            link        fb  \
# 0     'http://www.ruzzit.com/en-US/Redirect/Link?media=653892',   '1.2M',
# 1    'http://www.ruzzit.com/en-US/Redirect/Link?media=1928328',   '5.1M',
# 2    'http://www.ruzzit.com/en-US/Redirect/Link?media=1927663',   '4.1M',
# 3    'http://www.ruzzit.com/en-US/Redirect/Link?media=1960941',     '3M',
# 4    'http://www.ruzzit.com/en-US/Redirect/Link?media=1931505',   '2.4M',
# 5    'http://www.ruzzit.com/en-US/Redirect/Link?media=1082319',   '1.6M',
# 6     'http://www.ruzzit.com/en-US/Redirect/Link?media=769705',   '1.4M',
# 7    'http://www.ruzzit.com/en-US/Redirect/Link?media=1074827',
# 8    'http://www.ruzzit.com/en-US/Redirect/Link?media=1689188',
# 9    'http://www.ruzzit.com/en-US/Redirect/Link?media=1432177',
# 10   'http://www.ruzzit.com/en-US/Redirect/Link?media=1722227',
# 11   'http://www.ruzzit.com/en-US/Redirect/Link?media=1925600',
# 12   'http://www.ruzzit.com/en-US/Redirect/Link?media=1861255',
# 13   'http://www.ruzzit.com/en-US/Redirect/Link?media=1524072',   '1.1M',
# 14   'http://www.ruzzit.com/en-US/Redirect/Link?media=1821965',  '60.8k',
# 15   'http://www.ruzzit.com/en-US/Redirect/Link?media=1981872',     '1M',
# 16   'http://www.ruzzit.com/en-US/Redirect/Link?media=1019795',   '975k',
# 17    'http://www.ruzzit.com/en-US/Redirect/Link?media=638596',   '962k',
# 18    'http://www.ruzzit.com/en-US/Redirect/Link?media=727249',   '958k',
# 19   'http://www.ruzzit.com/en-US/Redirect/Link?media=1935494',   '945k',
# 20   'http://www.ruzzit.com/en-US/Redirect/Link?media=1376079',   '939k',
# 21   'http://www.ruzzit.com/en-US/Redirect/Link?media=1384460',   '900k',
# 22   'http://www.ruzzit.com/en-US/Redirect/Link?media=1174765',   '868k',
# 23   'http://www.ruzzit.com/en-US/Redirect/Link?media=1168165',   '866k',
# 24    'http://www.ruzzit.com/en-US/Redirect/Link?media=714360',   '860k',
# 25   'http://www.ruzzit.com/en-US/Redirect/Link?media=1422684',  '2,290',
# 26    'http://www.ruzzit.com/en-US/Redirect/Link?media=558599',   '807k',
# 27    'http://www.ruzzit.com/en-US/Redirect/Link?media=826556',   '824k',
# 28    'http://www.ruzzit.com/en-US/Redirect/Link?media=996126',   '812k',
# 29    'http://www.ruzzit.com/en-US/Redirect/Link?media=915868',   '763k',
# ..                                                          ...       ...
# 480  'http://www.ruzzit.com/en-US/Redirect/Link?media=1364952',
# 481  'http://www.ruzzit.com/en-US/Redirect/Link?media=1748005',   '181k',
# 482   'http://www.ruzzit.com/en-US/Redirect/Link?media=818225',
# 483  'http://www.ruzzit.com/en-US/Redirect/Link?media=1672321',   '182k',
# 484  'http://www.ruzzit.com/en-US/Redirect/Link?media=1257135',
# 485   'http://www.ruzzit.com/en-US/Redirect/Link?media=733598',
# 486  'http://www.ruzzit.com/en-US/Redirect/Link?media=1696278',
# 487  'http://www.ruzzit.com/en-US/Redirect/Link?media=1487290',
# 488  'http://www.ruzzit.com/en-US/Redirect/Link?media=1679409',
# 489  'http://www.ruzzit.com/en-US/Redirect/Link?media=1743267',
# 490  'http://www.ruzzit.com/en-US/Redirect/Link?media=1985649',
# 491  'http://www.ruzzit.com/en-US/Redirect/Link?media=1696239',   '171k',
# 492   'http://www.ruzzit.com/en-US/Redirect/Link?media=655490',
# 493   'http://www.ruzzit.com/en-US/Redirect/Link?media=545119',
# 494   'http://www.ruzzit.com/en-US/Redirect/Link?media=679940',
# 495   'http://www.ruzzit.com/en-US/Redirect/Link?media=682798',
# 496   'http://www.ruzzit.com/en-US/Redirect/Link?media=761373',
# 497  'http://www.ruzzit.com/en-US/Redirect/Link?media=1066878',
# 498   'http://www.ruzzit.com/en-US/Redirect/Link?media=927520',
# 499  'http://www.ruzzit.com/en-US/Redirect/Link?media=1095642',
# 500  'http://www.ruzzit.com/en-US/Redirect/Link?media=1425704',
# 501  'http://www.ruzzit.com/en-US/Redirect/Link?media=1856366',
# 502   'http://www.ruzzit.com/en-US/Redirect/Link?media=574850',
# 503  'http://www.ruzzit.com/en-US/Redirect/Link?media=1594518',
# 504  'http://www.ruzzit.com/en-US/Redirect/Link?media=1467108',
# 505  'http://www.ruzzit.com/en-US/Redirect/Link?media=1416921',
# 506   'http://www.ruzzit.com/en-US/Redirect/Link?media=634623',
# 507   'http://www.ruzzit.com/en-US/Redirect/Link?media=606885',   '176k',
# 508  'http://www.ruzzit.com/en-US/Redirect/Link?media=1515874',   '169k',
# 509  'http://www.ruzzit.com/en-US/Redirect/Link?media=1286067',
#
#          lnkdn      pins                  date
# 0    '1,911 ',  '8,693',   '18/3/2015 18:41'),
# 1    '1,559 ',  '10.9k',   '24/1/2016 21:00'),
# 2       '76 ',  '5,465',   '24/1/2016 15:15'),
# 3        '0 ',  '2,760',    '1/2/2016 03:46'),
# 4       '17 ',    '302',   '15/1/2016 15:24'),
# 5    '1,090 ',    '313',   '30/6/2015 20:34'),
# 6      '595 ',      '1',   '15/4/2015 20:48'),
# 7       '15 ',     '14',   '26/6/2015 21:31'),
# 8        '1 ',     '10',    '8/9/2015 22:01'),
# 9      '201 ',    '418',   '22/9/2015 23:02'),
# 10                  '0',  '27/11/2015 18:03'),
# 11                '110',   '15/1/2016 11:23'),
# 12                 '96',   '28/7/2015 09:30'),
# 13     '115 ',    '266',  '18/10/2015 21:58'),
# 14      '69 ',   '954k',  '30/12/2015 16:13'),
# 15     '295 ',     '16',   '29/1/2016 16:04'),
# 16   '2,937 ',    '549',   '19/6/2015 01:51'),
# 17                '204',   '14/3/2015 14:31'),
# 18     '188 ',    '104',    '4/4/2015 15:00'),
# 19       '2 ',  '1,072',   '26/1/2016 10:13'),
# 20     '121 ',    '107',    '6/9/2015 17:23'),
# 21      '98 ',     '79',   '11/9/2015 16:07'),
# 22     '807 ',    '500',   '23/7/2015 13:07'),
# 23     '911 ',     '59',   '20/7/2015 20:02'),
# 24     '198 ',    '704',    '6/4/2015 05:01'),
# 25       '8 ',             '15/9/2015 16:41'),
# 26   '8,290 ',  '29.7k',   '21/2/2015 17:02'),
# 27     '195 ',    '211',   '30/4/2015 01:01'),
# 28     '280 ',             '13/6/2015 07:57'),
# 29      '19 ',  '47.2k',   '23/5/2015 18:15'),
# ..         ...       ...                   ...
# 480                '25',   '10/9/2015 23:21'),
# 481  '1,525 ',     '68',  '12/12/2015 11:55'),
# 482  '2,508 ',              '1/5/2015 07:03'),
# 483    '284 ',            '16/11/2015 21:35'),
# 484    '364 ',             '16/8/2015 01:41'),
# 485                        '10/4/2015 20:45'),
# 486                       '30/11/2015 19:15'),
# 487    '975 ',    '183',  '10/10/2015 03:24'),
# 488               '993',  '26/11/2015 12:16'),
# 489                       '11/12/2015 08:24'),
# 490                         '1/2/2016 00:40'),
# 491  '10.3k ',            '30/11/2015 21:09'),
# 492                        '19/3/2015 04:31'),
# 493               '308',   '17/2/2015 15:00'),
# 494                        '26/3/2015 14:47'),
# 495  '1,179 ',             '24/3/2015 05:00'),
# 496     '40 ',             '17/4/2015 05:14'),
# 497                        '26/6/2015 20:18'),
# 498    '165 ',             '27/5/2015 02:55'),
# 499                         '8/7/2015 00:26'),
# 500  '4,980 ',             '18/9/2015 18:45'),
# 501                         '8/1/2016 00:25'),
# 502                '65',   '26/2/2015 01:39'),
# 503    '139 ',     '87',   '5/11/2015 17:48'),
# 504               '295',    '8/7/2015 12:25'),
# 505                        '23/9/2015 08:58'),
# 506    '380 ',             '13/3/2015 15:42'),
# 507    '417 ',              '2/3/2015 19:21'),
# 508    '517 ',    '135',  '13/10/2015 15:18'),
# 509                         '18/8/2015 22:55')
#
# [510 rows x 6 columns]
